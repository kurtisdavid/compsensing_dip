# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1, 5)
for i in range(5):
    me = np.load('noisy_'+str(i)+'.npy')
    ax[i].imshow(me.reshape(14,14))

# %%
fig, ax = plt.subplots(1, 5)
for i in range(5):
    me = np.load('im'+str(i+1)+'.npy')
    ax[i].imshow(me.squeeze())

# %%
re1 = np.load('im1.npy')
me1 = np.load('noisy_0.npy')

# %%
plt.imshow(me1.reshape(14,14))

# %%
plt.imshow(re1.squeeze())
